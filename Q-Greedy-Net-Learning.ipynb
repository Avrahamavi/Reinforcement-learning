# %% [markdown]
# # Q-Network Learning

# %%
import gym
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load the environment

# %%
env = gym.make('FrozenLake-v0')
# Out:
# [2017-01-31 16:48:37,568] Making new env: FrozenLake-v0

# %% [markdown]
# ## The Q-Network Approach

# %% [markdown]
# ### Implementing the network itself

# %%
tf.reset_default_graph()

# %%
#These lines establish the feed-forward part of the network used to choose actions
inputs1 = tf.placeholder(shape=[1,16],dtype=tf.float32)
W = tf.Variable(tf.random_uniform([16,4],0,0.01))
Qout = tf.matmul(inputs1,W)
predict = tf.argmax(Qout,1)

#Below we obtain the loss by taking the sum of squares difference between the target and prediction Q values.
nextQ = tf.placeholder(shape=[1,4],dtype=tf.float32)
loss = tf.reduce_sum(tf.square(nextQ - Qout))
trainer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
updateModel = trainer.minimize(loss)

# %% [markdown]
# ### Training the network

# %%
init = tf.global_variables_initializer()

# Set learning parameters
y = .99
e = 0.1
num_episodes = 2000
#create lists to contain total rewards and steps per episode
jList = []
rList = []
with tf.Session() as sess:
    sess.run(init)
    for i in range(num_episodes):
        #Reset environment and get first new observation
        s = env.reset()
        rAll = 0
        d = False
        j = 0
        #The Q-Network
        while j < 99:
            j+=1
            #Choose an action by greedily (with e chance of random action) from the Q-network
            a,targetQ = sess.run([predict,Qout],feed_dict={inputs1:np.identity(16)[s:s+1]})

            if np.random.rand(1) < e:
                a[0] = env.action_space.sample()
            #Get new state and reward from environment
            s1,r,d,_ = env.step(a[0])
            #Obtain the Q' values by feeding the new state through our network
            Q1 = sess.run(Qout,feed_dict={inputs1:np.identity(16)[s1:s1+1]})
            #Obtain maxQ' and set our target value for chosen action.
            maxQ1 = np.max(Q1)
            targetQ[0,a[0]] = r + y*maxQ1
            #Train our network using target and predicted Q values
            _,_ = sess.run([updateModel,W],feed_dict={inputs1:np.identity(16)[s:s+1],nextQ:targetQ})
            rAll += r
            s = s1
            if d == True:
                #Reduce chance of random action as we train the model.
                e = 1./((i/50) + 10)
                if rAll == 1.0:
                    strr = "Success"
                else:
                    strr = "Game over"
                print "Game %d played until step %d: %s, final reward=%s" % (i,j,strr,rAll)
                break
        jList.append(j)
        rList.append(rAll)
print "Percent of succesful episodes: " + str(100*sum(rList)/num_episodes) + "%"
# Out:
# Game 0 played until step 10: Game over, final reward=0.0
# Game 1 played until step 4: Game over, final reward=0.0
# Game 2 played until step 10: Game over, final reward=0.0
# Game 3 played until step 3: Game over, final reward=0.0
# Game 4 played until step 3: Game over, final reward=0.0
# Game 5 played until step 7: Game over, final reward=0.0
# Game 6 played until step 2: Game over, final reward=0.0
# Game 7 played until step 11: Game over, final reward=0.0
# Game 8 played until step 4: Game over, final reward=0.0
# Game 9 played until step 5: Game over, final reward=0.0
# Game 10 played until step 19: Game over, final reward=0.0
# Game 11 played until step 7: Game over, final reward=0.0
# Game 12 played until step 3: Game over, final reward=0.0
# Game 13 played until step 2: Game over, final reward=0.0
# Game 14 played until step 4: Game over, final reward=0.0
# Game 15 played until step 12: Game over, final reward=0.0
# Game 16 played until step 6: Game over, final reward=0.0
# Game 17 played until step 12: Game over, final reward=0.0
# Game 18 played until step 2: Game over, final reward=0.0
# Game 19 played until step 25: Game over, final reward=0.0
# Game 20 played until step 4: Game over, final reward=0.0
# Game 21 played until step 2: Game over, final reward=0.0
# Game 22 played until step 13: Game over, final reward=0.0
# Game 23 played until step 6: Game over, final reward=0.0
# Game 24 played until step 2: Game over, final reward=0.0
# Game 25 played until step 2: Game over, final reward=0.0
# Game 26 played until step 17: Game over, final reward=0.0
# Game 27 played until step 4: Game over, final reward=0.0
# Game 28 played until step 2: Game over, final reward=0.0
# Game 29 played until step 3: Game over, final reward=0.0
# Game 30 played until step 9: Game over, final reward=0.0
# Game 31 played until step 7: Game over, final reward=0.0
# Game 32 played until step 3: Game over, final reward=0.0
# Game 33 played until step 3: Game over, final reward=0.0
# Game 34 played until step 5: Game over, final reward=0.0
# Game 35 played until step 7: Game over, final reward=0.0
# Game 36 played until step 7: Game over, final reward=0.0
# Game 37 played until step 11: Game over, final reward=0.0
# Game 38 played until step 5: Game over, final reward=0.0
# Game 39 played until step 12: Game over, final reward=0.0
# Game 40 played until step 8: Game over, final reward=0.0
# Game 41 played until step 6: Game over, final reward=0.0
# Game 42 played until step 2: Game over, final reward=0.0
# Game 43 played until step 2: Game over, final reward=0.0
# Game 44 played until step 7: Game over, final reward=0.0
# Game 45 played until step 4: Game over, final reward=0.0
# Game 46 played until step 8: Game over, final reward=0.0
# Game 47 played until step 2: Game over, final reward=0.0
# Game 48 played until step 2: Game over, final reward=0.0
# Game 49 played until step 10: Game over, final reward=0.0
# Game 50 played until step 3: Game over, final reward=0.0
# Game 51 played until step 2: Game over, final reward=0.0
# Game 52 played until step 14: Game over, final reward=0.0
# Game 53 played until step 11: Game over, final reward=0.0
# Game 54 played until step 8: Game over, final reward=0.0
# Game 55 played until step 6: Game over, final reward=0.0
# Game 56 played until step 3: Game over, final reward=0.0
# Game 57 played until step 3: Game over, final reward=0.0
# Game 58 played until step 7: Game over, final reward=0.0
# Game 59 played until step 7: Game over, final reward=0.0
# Game 60 played until step 5: Game over, final reward=0.0
# Game 61 played until step 3: Game over, final reward=0.0
# Game 62 played until step 7: Game over, final reward=0.0
# Game 63 played until step 12: Game over, final reward=0.0
# Game 64 played until step 9: Game over, final reward=0.0
# Game 65 played until step 6: Game over, final reward=0.0
# Game 66 played until step 2: Game over, final reward=0.0
# Game 67 played until step 2: Game over, final reward=0.0
# Game 68 played until step 10: Game over, final reward=0.0
# Game 69 played until step 7: Game over, final reward=0.0
# Game 70 played until step 3: Game over, final reward=0.0
# Game 71 played until step 3: Game over, final reward=0.0
# Game 72 played until step 6: Game over, final reward=0.0
# Game 73 played until step 4: Game over, final reward=0.0
# Game 74 played until step 2: Game over, final reward=0.0
# Game 75 played until step 2: Game over, final reward=0.0
# Game 76 played until step 6: Game over, final reward=0.0
# Game 77 played until step 2: Game over, final reward=0.0
# Game 78 played until step 4: Game over, final reward=0.0
# Game 79 played until step 2: Game over, final reward=0.0
# Game 80 played until step 2: Game over, final reward=0.0
# Game 81 played until step 4: Game over, final reward=0.0
# Game 82 played until step 8: Game over, final reward=0.0
# Game 83 played until step 25: Game over, final reward=0.0
# Game 84 played until step 6: Game over, final reward=0.0
# Game 85 played until step 16: Success, final reward=1.0
# Game 86 played until step 3: Game over, final reward=0.0
# Game 87 played until step 3: Game over, final reward=0.0
# Game 88 played until step 5: Game over, final reward=0.0
# Game 89 played until step 2: Game over, final reward=0.0
# Game 90 played until step 4: Game over, final reward=0.0
# Game 91 played until step 2: Game over, final reward=0.0
# Game 92 played until step 3: Game over, final reward=0.0
# Game 93 played until step 8: Game over, final reward=0.0
# Game 94 played until step 6: Game over, final reward=0.0
# Game 95 played until step 4: Game over, final reward=0.0
# Game 96 played until step 6: Game over, final reward=0.0
# Game 97 played until step 2: Game over, final reward=0.0
# Game 98 played until step 2: Game over, final reward=0.0
# Game 99 played until step 4: Game over, final reward=0.0
# Game 100 played until step 14: Game over, final reward=0.0
# Game 101 played until step 5: Game over, final reward=0.0
# Game 102 played until step 9: Game over, final reward=0.0
# Game 103 played until step 16: Game over, final reward=0.0
# Game 104 played until step 13: Game over, final reward=0.0
# Game 105 played until step 5: Game over, final reward=0.0
# Game 106 played until step 6: Game over, final reward=0.0
# Game 107 played until step 2: Game over, final reward=0.0
# Game 108 played until step 14: Game over, final reward=0.0
# Game 109 played until step 2: Game over, final reward=0.0
# Game 110 played until step 10: Game over, final reward=0.0
# Game 111 played until step 14: Game over, final reward=0.0
# Game 112 played until step 9: Game over, final reward=0.0
# Game 113 played until step 3: Game over, final reward=0.0
# Game 114 played until step 7: Game over, final reward=0.0
# Game 115 played until step 10: Game over, final reward=0.0
# Game 116 played until step 9: Game over, final reward=0.0
# Game 117 played until step 3: Game over, final reward=0.0
# Game 118 played until step 5: Game over, final reward=0.0
# Game 119 played until step 2: Game over, final reward=0.0
# Game 120 played until step 2: Game over, final reward=0.0
# Game 121 played until step 2: Game over, final reward=0.0
# Game 122 played until step 14: Game over, final reward=0.0
# Game 123 played until step 5: Game over, final reward=0.0
# Game 124 played until step 3: Game over, final reward=0.0
# Game 125 played until step 2: Game over, final reward=0.0
# Game 126 played until step 8: Game over, final reward=0.0
# Game 127 played until step 9: Game over, final reward=0.0
# Game 128 played until step 9: Game over, final reward=0.0
# Game 129 played until step 2: Game over, final reward=0.0
# Game 130 played until step 3: Game over, final reward=0.0
# Game 131 played until step 7: Game over, final reward=0.0
# Game 132 played until step 8: Game over, final reward=0.0
# Game 133 played until step 8: Game over, final reward=0.0
# Game 134 played until step 35: Game over, final reward=0.0
# Game 135 played until step 2: Game over, final reward=0.0
# Game 136 played until step 2: Game over, final reward=0.0
# Game 137 played until step 4: Game over, final reward=0.0
# Game 138 played until step 2: Game over, final reward=0.0
# Game 139 played until step 14: Game over, final reward=0.0
# Game 140 played until step 2: Game over, final reward=0.0
# Game 141 played until step 8: Game over, final reward=0.0
# Game 142 played until step 4: Game over, final reward=0.0
# Game 143 played until step 3: Game over, final reward=0.0
# Game 144 played until step 4: Game over, final reward=0.0
# Game 145 played until step 8: Game over, final reward=0.0
# Game 146 played until step 27: Game over, final reward=0.0
# Game 147 played until step 7: Game over, final reward=0.0
# Game 148 played until step 8: Game over, final reward=0.0
# Game 149 played until step 5: Game over, final reward=0.0
# Game 150 played until step 2: Game over, final reward=0.0
# Game 151 played until step 5: Game over, final reward=0.0
# Game 152 played until step 16: Game over, final reward=0.0
# Game 153 played until step 7: Game over, final reward=0.0
# Game 154 played until step 5: Game over, final reward=0.0
# Game 155 played until step 3: Game over, final reward=0.0
# Game 156 played until step 4: Game over, final reward=0.0
# Game 157 played until step 6: Game over, final reward=0.0
# Game 158 played until step 9: Game over, final reward=0.0
# Game 159 played until step 9: Game over, final reward=0.0
# Game 160 played until step 2: Game over, final reward=0.0
# Game 161 played until step 2: Game over, final reward=0.0
# Game 162 played until step 6: Game over, final reward=0.0
# Game 163 played until step 8: Game over, final reward=0.0
# Game 164 played until step 2: Game over, final reward=0.0
# Game 165 played until step 15: Game over, final reward=0.0
# Game 166 played until step 11: Game over, final reward=0.0
# Game 167 played until step 5: Game over, final reward=0.0
# Game 168 played until step 5: Game over, final reward=0.0
# Game 169 played until step 15: Game over, final reward=0.0
# Game 170 played until step 2: Game over, final reward=0.0
# Game 171 played until step 3: Game over, final reward=0.0
# Game 172 played until step 10: Game over, final reward=0.0
# Game 173 played until step 7: Game over, final reward=0.0
# Game 174 played until step 9: Game over, final reward=0.0
# Game 175 played until step 11: Game over, final reward=0.0
# Game 176 played until step 7: Game over, final reward=0.0
# Game 177 played until step 3: Game over, final reward=0.0
# Game 178 played until step 2: Game over, final reward=0.0
# Game 179 played until step 5: Game over, final reward=0.0
# Game 180 played until step 5: Game over, final reward=0.0
# Game 181 played until step 6: Game over, final reward=0.0
# Game 182 played until step 7: Game over, final reward=0.0
# Game 183 played until step 2: Game over, final reward=0.0
# Game 184 played until step 2: Game over, final reward=0.0
# Game 185 played until step 7: Game over, final reward=0.0
# Game 186 played until step 17: Success, final reward=1.0
# Game 187 played until step 3: Game over, final reward=0.0
# Game 188 played until step 2: Game over, final reward=0.0
# Game 189 played until step 8: Game over, final reward=0.0
# Game 190 played until step 4: Game over, final reward=0.0
# Game 191 played until step 7: Game over, final reward=0.0
# Game 192 played until step 11: Success, final reward=1.0
# Game 193 played until step 5: Game over, final reward=0.0
# Game 194 played until step 9: Game over, final reward=0.0
# Game 195 played until step 15: Game over, final reward=0.0
# Game 196 played until step 3: Game over, final reward=0.0
# Game 197 played until step 17: Game over, final reward=0.0
# Game 198 played until step 5: Game over, final reward=0.0
# Game 199 played until step 10: Game over, final reward=0.0
# Game 200 played until step 3: Game over, final reward=0.0
# Game 201 played until step 8: Game over, final reward=0.0
# Game 202 played until step 18: Game over, final reward=0.0
# Game 203 played until step 2: Game over, final reward=0.0
# Game 204 played until step 2: Game over, final reward=0.0
# Game 205 played until step 4: Game over, final reward=0.0
# Game 206 played until step 4: Game over, final reward=0.0
# Game 207 played until step 3: Game over, final reward=0.0
# Game 208 played until step 10: Game over, final reward=0.0
# Game 209 played until step 2: Game over, final reward=0.0
# Game 210 played until step 8: Game over, final reward=0.0
# Game 211 played until step 8: Success, final reward=1.0
# Game 212 played until step 4: Game over, final reward=0.0
# Game 213 played until step 12: Game over, final reward=0.0
# Game 214 played until step 5: Game over, final reward=0.0
# Game 215 played until step 17: Game over, final reward=0.0
# Game 216 played until step 3: Game over, final reward=0.0
# Game 217 played until step 2: Game over, final reward=0.0
# Game 218 played until step 4: Game over, final reward=0.0
# Game 219 played until step 21: Game over, final reward=0.0
# Game 220 played until step 2: Game over, final reward=0.0
# Game 221 played until step 2: Game over, final reward=0.0
# Game 222 played until step 4: Game over, final reward=0.0
# Game 223 played until step 4: Game over, final reward=0.0
# Game 224 played until step 2: Game over, final reward=0.0
# Game 225 played until step 17: Game over, final reward=0.0
# Game 226 played until step 4: Game over, final reward=0.0
# Game 227 played until step 5: Game over, final reward=0.0
# Game 228 played until step 5: Game over, final reward=0.0
# Game 229 played until step 11: Game over, final reward=0.0
# Game 230 played until step 8: Game over, final reward=0.0
# Game 231 played until step 2: Game over, final reward=0.0
# Game 232 played until step 7: Game over, final reward=0.0
# Game 233 played until step 5: Game over, final reward=0.0
# Game 234 played until step 3: Game over, final reward=0.0
# Game 235 played until step 4: Game over, final reward=0.0
# Game 236 played until step 4: Game over, final reward=0.0
# Game 237 played until step 15: Game over, final reward=0.0
# Game 238 played until step 11: Game over, final reward=0.0
# Game 239 played until step 10: Game over, final reward=0.0
# Game 240 played until step 2: Game over, final reward=0.0
# Game 241 played until step 5: Game over, final reward=0.0
# Game 242 played until step 11: Game over, final reward=0.0
# Game 243 played until step 8: Game over, final reward=0.0
# Game 244 played until step 3: Game over, final reward=0.0
# Game 245 played until step 6: Game over, final reward=0.0
# Game 246 played until step 2: Game over, final reward=0.0
# Game 247 played until step 2: Game over, final reward=0.0
# Game 248 played until step 16: Game over, final reward=0.0
# Game 249 played until step 2: Game over, final reward=0.0
# Game 250 played until step 7: Game over, final reward=0.0
# Game 251 played until step 6: Game over, final reward=0.0
# Game 252 played until step 9: Game over, final reward=0.0
# Game 253 played until step 7: Game over, final reward=0.0
# Game 254 played until step 5: Game over, final reward=0.0
# Game 255 played until step 7: Game over, final reward=0.0
# Game 256 played until step 9: Game over, final reward=0.0
# Game 257 played until step 7: Game over, final reward=0.0
# Game 258 played until step 21: Game over, final reward=0.0
# Game 259 played until step 10: Game over, final reward=0.0
# Game 260 played until step 8: Game over, final reward=0.0
# Game 261 played until step 4: Game over, final reward=0.0
# Game 262 played until step 8: Game over, final reward=0.0
# Game 263 played until step 33: Success, final reward=1.0
# Game 264 played until step 22: Game over, final reward=0.0
# Game 265 played until step 11: Game over, final reward=0.0
# Game 266 played until step 6: Game over, final reward=0.0
# Game 267 played until step 5: Game over, final reward=0.0
# Game 268 played until step 11: Game over, final reward=0.0
# Game 269 played until step 12: Game over, final reward=0.0
# Game 270 played until step 5: Game over, final reward=0.0
# Game 271 played until step 22: Game over, final reward=0.0
# Game 272 played until step 3: Game over, final reward=0.0
# Game 273 played until step 8: Game over, final reward=0.0
# Game 274 played until step 5: Game over, final reward=0.0
# Game 275 played until step 29: Success, final reward=1.0
# Game 276 played until step 22: Game over, final reward=0.0
# Game 277 played until step 14: Game over, final reward=0.0
# Game 278 played until step 5: Game over, final reward=0.0
# Game 279 played until step 5: Game over, final reward=0.0
# Game 280 played until step 4: Game over, final reward=0.0
# Game 281 played until step 6: Game over, final reward=0.0
# Game 282 played until step 2: Game over, final reward=0.0
# Game 283 played until step 18: Success, final reward=1.0
# Game 284 played until step 23: Game over, final reward=0.0
# Game 285 played until step 12: Game over, final reward=0.0
# Game 286 played until step 19: Game over, final reward=0.0
# Game 287 played until step 2: Game over, final reward=0.0
# Game 288 played until step 12: Game over, final reward=0.0
# Game 289 played until step 20: Game over, final reward=0.0
# Game 290 played until step 4: Game over, final reward=0.0
# Game 291 played until step 5: Game over, final reward=0.0
# Game 292 played until step 3: Game over, final reward=0.0
# Game 293 played until step 9: Game over, final reward=0.0
# Game 294 played until step 17: Game over, final reward=0.0
# Game 295 played until step 13: Game over, final reward=0.0
# Game 296 played until step 6: Game over, final reward=0.0
# Game 297 played until step 6: Game over, final reward=0.0
# Game 298 played until step 21: Game over, final reward=0.0
# Game 299 played until step 4: Game over, final reward=0.0
# Game 300 played until step 3: Game over, final reward=0.0
# Game 301 played until step 3: Game over, final reward=0.0
# Game 302 played until step 19: Game over, final reward=0.0
# Game 303 played until step 15: Success, final reward=1.0
# Game 304 played until step 13: Game over, final reward=0.0
# Game 305 played until step 3: Game over, final reward=0.0
# Game 306 played until step 22: Game over, final reward=0.0
# Game 307 played until step 7: Game over, final reward=0.0
# Game 308 played until step 5: Game over, final reward=0.0
# Game 309 played until step 28: Success, final reward=1.0
# Game 310 played until step 10: Game over, final reward=0.0
# Game 311 played until step 16: Game over, final reward=0.0
# Game 312 played until step 9: Game over, final reward=0.0
# Game 313 played until step 18: Game over, final reward=0.0
# Game 314 played until step 6: Game over, final reward=0.0
# Game 315 played until step 24: Game over, final reward=0.0
# Game 316 played until step 21: Success, final reward=1.0
# Game 317 played until step 22: Game over, final reward=0.0
# Game 318 played until step 4: Game over, final reward=0.0
# Game 319 played until step 7: Game over, final reward=0.0
# Game 320 played until step 8: Game over, final reward=0.0
# Game 321 played until step 5: Game over, final reward=0.0
# Game 322 played until step 11: Game over, final reward=0.0
# Game 323 played until step 20: Game over, final reward=0.0
# Game 324 played until step 25: Game over, final reward=0.0
# Game 325 played until step 8: Game over, final reward=0.0
# Game 326 played until step 11: Game over, final reward=0.0
# Game 327 played until step 29: Game over, final reward=0.0
# Game 328 played until step 12: Game over, final reward=0.0
# Game 329 played until step 18: Game over, final reward=0.0
# Game 330 played until step 22: Success, final reward=1.0
# Game 331 played until step 54: Game over, final reward=0.0
# Game 332 played until step 12: Game over, final reward=0.0
# Game 333 played until step 12: Success, final reward=1.0
# Game 334 played until step 16: Game over, final reward=0.0
# Game 335 played until step 16: Game over, final reward=0.0
# Game 336 played until step 39: Game over, final reward=0.0
# Game 337 played until step 26: Game over, final reward=0.0
# Game 338 played until step 19: Success, final reward=1.0
# Game 339 played until step 13: Game over, final reward=0.0
# Game 340 played until step 40: Game over, final reward=0.0
# Game 341 played until step 7: Game over, final reward=0.0
# Game 342 played until step 19: Game over, final reward=0.0
# Game 343 played until step 10: Game over, final reward=0.0
# Game 344 played until step 5: Game over, final reward=0.0
# Game 345 played until step 39: Game over, final reward=0.0
# Game 346 played until step 17: Game over, final reward=0.0
# Game 347 played until step 13: Game over, final reward=0.0
# Game 348 played until step 36: Game over, final reward=0.0
# Game 349 played until step 7: Game over, final reward=0.0
# Game 350 played until step 7: Game over, final reward=0.0
# Game 351 played until step 13: Game over, final reward=0.0
# Game 352 played until step 19: Game over, final reward=0.0
# Game 353 played until step 16: Success, final reward=1.0
# Game 354 played until step 8: Game over, final reward=0.0
# Game 355 played until step 13: Game over, final reward=0.0
# Game 356 played until step 8: Game over, final reward=0.0
# Game 357 played until step 12: Game over, final reward=0.0
# Game 358 played until step 23: Success, final reward=1.0
# Game 359 played until step 6: Success, final reward=1.0
# Game 360 played until step 49: Game over, final reward=0.0
# Game 361 played until step 12: Game over, final reward=0.0
# Game 362 played until step 32: Success, final reward=1.0
# Game 363 played until step 17: Game over, final reward=0.0
# Game 364 played until step 22: Game over, final reward=0.0
# Game 365 played until step 24: Game over, final reward=0.0
# Game 366 played until step 9: Success, final reward=1.0
# Game 367 played until step 10: Game over, final reward=0.0
# Game 368 played until step 11: Game over, final reward=0.0
# Game 369 played until step 15: Game over, final reward=0.0
# Game 370 played until step 52: Success, final reward=1.0
# Game 371 played until step 42: Game over, final reward=0.0
# Game 372 played until step 6: Game over, final reward=0.0
# Game 373 played until step 68: Game over, final reward=0.0
# Game 374 played until step 26: Game over, final reward=0.0
# Game 375 played until step 12: Game over, final reward=0.0
# Game 376 played until step 20: Game over, final reward=0.0
# Game 377 played until step 18: Game over, final reward=0.0
# Game 378 played until step 13: Game over, final reward=0.0
# Game 379 played until step 39: Game over, final reward=0.0
# Game 380 played until step 15: Success, final reward=1.0
# Game 381 played until step 15: Game over, final reward=0.0
# Game 382 played until step 22: Game over, final reward=0.0
# Game 383 played until step 13: Success, final reward=1.0
# Game 384 played until step 18: Game over, final reward=0.0
# Game 385 played until step 10: Game over, final reward=0.0
# Game 386 played until step 66: Game over, final reward=0.0
# Game 387 played until step 22: Game over, final reward=0.0
# Game 388 played until step 31: Game over, final reward=0.0
# Game 389 played until step 15: Game over, final reward=0.0
# Game 390 played until step 15: Game over, final reward=0.0
# Game 391 played until step 16: Game over, final reward=0.0
# Game 392 played until step 4: Game over, final reward=0.0
# Game 393 played until step 10: Game over, final reward=0.0
# Game 394 played until step 9: Game over, final reward=0.0
# Game 395 played until step 40: Game over, final reward=0.0
# Game 396 played until step 21: Success, final reward=1.0
# Game 397 played until step 18: Game over, final reward=0.0
# Game 398 played until step 29: Success, final reward=1.0
# Game 399 played until step 14: Game over, final reward=0.0
# Game 400 played until step 44: Game over, final reward=0.0
# Game 401 played until step 32: Game over, final reward=0.0
# Game 402 played until step 12: Game over, final reward=0.0
# Game 403 played until step 24: Success, final reward=1.0
# Game 404 played until step 16: Game over, final reward=0.0
# Game 405 played until step 12: Success, final reward=1.0
# Game 406 played until step 30: Game over, final reward=0.0
# Game 407 played until step 22: Game over, final reward=0.0
# Game 408 played until step 15: Game over, final reward=0.0
# Game 409 played until step 12: Game over, final reward=0.0
# Game 410 played until step 34: Game over, final reward=0.0
# Game 411 played until step 19: Game over, final reward=0.0
# Game 412 played until step 7: Game over, final reward=0.0
# Game 413 played until step 50: Success, final reward=1.0
# Game 414 played until step 40: Game over, final reward=0.0
# Game 415 played until step 12: Game over, final reward=0.0
# Game 416 played until step 5: Game over, final reward=0.0
# Game 417 played until step 19: Game over, final reward=0.0
# Game 418 played until step 16: Game over, final reward=0.0
# Game 419 played until step 38: Game over, final reward=0.0
# Game 420 played until step 68: Game over, final reward=0.0
# Game 421 played until step 22: Game over, final reward=0.0
# Game 422 played until step 7: Game over, final reward=0.0
# Game 423 played until step 7: Game over, final reward=0.0
# Game 424 played until step 13: Game over, final reward=0.0
# Game 425 played until step 8: Game over, final reward=0.0
# Game 426 played until step 17: Game over, final reward=0.0
# Game 427 played until step 11: Success, final reward=1.0
# Game 428 played until step 18: Game over, final reward=0.0
# Game 429 played until step 34: Game over, final reward=0.0
# Game 430 played until step 17: Game over, final reward=0.0
# Game 431 played until step 29: Game over, final reward=0.0
# Game 432 played until step 6: Game over, final reward=0.0
# Game 433 played until step 15: Game over, final reward=0.0
# Game 434 played until step 44: Success, final reward=1.0
# Game 435 played until step 5: Game over, final reward=0.0
# Game 436 played until step 29: Game over, final reward=0.0
# Game 437 played until step 35: Game over, final reward=0.0
# Game 438 played until step 26: Game over, final reward=0.0
# Game 439 played until step 4: Game over, final reward=0.0
# Game 440 played until step 10: Game over, final reward=0.0
# Game 441 played until step 15: Game over, final reward=0.0
# Game 442 played until step 16: Success, final reward=1.0
# Game 443 played until step 21: Game over, final reward=0.0
# Game 444 played until step 35: Game over, final reward=0.0
# Game 445 played until step 21: Success, final reward=1.0
# Game 446 played until step 12: Success, final reward=1.0
# Game 447 played until step 9: Game over, final reward=0.0
# Game 448 played until step 6: Game over, final reward=0.0
# Game 449 played until step 29: Game over, final reward=0.0
# Game 450 played until step 12: Game over, final reward=0.0
# Game 451 played until step 19: Success, final reward=1.0
# Game 452 played until step 3: Game over, final reward=0.0
# Game 453 played until step 12: Game over, final reward=0.0
# Game 454 played until step 8: Game over, final reward=0.0
# Game 455 played until step 8: Game over, final reward=0.0
# Game 456 played until step 20: Game over, final reward=0.0
# Game 457 played until step 6: Game over, final reward=0.0
# Game 458 played until step 18: Game over, final reward=0.0
# Game 459 played until step 10: Game over, final reward=0.0
# Game 460 played until step 18: Success, final reward=1.0
# Game 461 played until step 16: Success, final reward=1.0
# Game 462 played until step 16: Game over, final reward=0.0
# Game 463 played until step 8: Game over, final reward=0.0
# Game 464 played until step 8: Game over, final reward=0.0
# Game 465 played until step 11: Game over, final reward=0.0
# Game 466 played until step 30: Success, final reward=1.0
# Game 467 played until step 25: Game over, final reward=0.0
# Game 468 played until step 18: Game over, final reward=0.0
# Game 469 played until step 27: Game over, final reward=0.0
# Game 470 played until step 10: Game over, final reward=0.0
# Game 471 played until step 19: Game over, final reward=0.0
# Game 472 played until step 20: Game over, final reward=0.0
# Game 473 played until step 16: Game over, final reward=0.0
# Game 474 played until step 8: Game over, final reward=0.0
# Game 475 played until step 14: Game over, final reward=0.0
# Game 476 played until step 37: Game over, final reward=0.0
# Game 477 played until step 7: Game over, final reward=0.0
# Game 478 played until step 13: Game over, final reward=0.0
# Game 479 played until step 11: Game over, final reward=0.0
# Game 480 played until step 14: Game over, final reward=0.0
# Game 481 played until step 8: Game over, final reward=0.0
# Game 482 played until step 6: Game over, final reward=0.0
# Game 483 played until step 23: Game over, final reward=0.0
# Game 484 played until step 44: Game over, final reward=0.0
# Game 485 played until step 15: Game over, final reward=0.0
# Game 486 played until step 7: Game over, final reward=0.0
# Game 487 played until step 38: Game over, final reward=0.0
# Game 488 played until step 13: Game over, final reward=0.0
# Game 489 played until step 13: Game over, final reward=0.0
# Game 490 played until step 10: Game over, final reward=0.0
# Game 491 played until step 30: Game over, final reward=0.0
# Game 492 played until step 17: Success, final reward=1.0
# Game 493 played until step 35: Game over, final reward=0.0
# Game 494 played until step 12: Success, final reward=1.0
# Game 495 played until step 18: Game over, final reward=0.0
# Game 496 played until step 16: Success, final reward=1.0
# Game 497 played until step 17: Success, final reward=1.0
# Game 498 played until step 29: Game over, final reward=0.0
# Game 499 played until step 54: Success, final reward=1.0
# Game 500 played until step 14: Game over, final reward=0.0
# Game 501 played until step 59: Success, final reward=1.0
# Game 502 played until step 13: Game over, final reward=0.0
# Game 503 played until step 30: Success, final reward=1.0
# Game 504 played until step 51: Success, final reward=1.0
# Game 505 played until step 46: Game over, final reward=0.0
# Game 506 played until step 19: Success, final reward=1.0
# Game 507 played until step 85: Success, final reward=1.0
# Game 508 played until step 51: Game over, final reward=0.0
# Game 510 played until step 41: Success, final reward=1.0
# Game 511 played until step 10: Success, final reward=1.0
# Game 513 played until step 25: Game over, final reward=0.0
# Game 514 played until step 8: Game over, final reward=0.0
# Game 515 played until step 7: Game over, final reward=0.0
# Game 516 played until step 12: Game over, final reward=0.0
# Game 517 played until step 57: Game over, final reward=0.0
# Game 518 played until step 17: Game over, final reward=0.0
# Game 519 played until step 42: Game over, final reward=0.0
# Game 520 played until step 2: Game over, final reward=0.0
# Game 521 played until step 39: Game over, final reward=0.0
# Game 522 played until step 25: Game over, final reward=0.0
# Game 523 played until step 44: Game over, final reward=0.0
# Game 524 played until step 22: Game over, final reward=0.0
# Game 525 played until step 33: Game over, final reward=0.0
# Game 526 played until step 79: Game over, final reward=0.0
# Game 527 played until step 23: Game over, final reward=0.0
# Game 528 played until step 17: Game over, final reward=0.0
# Game 529 played until step 27: Success, final reward=1.0
# Game 530 played until step 8: Success, final reward=1.0
# Game 531 played until step 8: Success, final reward=1.0
# Game 532 played until step 67: Game over, final reward=0.0
# Game 533 played until step 8: Game over, final reward=0.0
# Game 534 played until step 31: Success, final reward=1.0
# Game 535 played until step 16: Game over, final reward=0.0
# Game 536 played until step 10: Game over, final reward=0.0
# Game 537 played until step 23: Success, final reward=1.0
# Game 538 played until step 13: Success, final reward=1.0
# Game 539 played until step 22: Game over, final reward=0.0
# Game 540 played until step 60: Success, final reward=1.0
# Game 541 played until step 5: Game over, final reward=0.0
# Game 542 played until step 29: Game over, final reward=0.0
# Game 543 played until step 13: Success, final reward=1.0
# Game 544 played until step 61: Game over, final reward=0.0
# Game 545 played until step 14: Success, final reward=1.0
# Game 546 played until step 40: Success, final reward=1.0
# Game 547 played until step 42: Game over, final reward=0.0
# Game 548 played until step 27: Game over, final reward=0.0
# Game 549 played until step 10: Game over, final reward=0.0
# Game 550 played until step 12: Game over, final reward=0.0
# Game 551 played until step 23: Game over, final reward=0.0
# Game 552 played until step 24: Success, final reward=1.0
# Game 553 played until step 6: Game over, final reward=0.0
# Game 554 played until step 25: Game over, final reward=0.0
# Game 555 played until step 16: Game over, final reward=0.0
# Game 556 played until step 7: Game over, final reward=0.0
# Game 557 played until step 24: Game over, final reward=0.0
# Game 558 played until step 15: Success, final reward=1.0
# Game 559 played until step 17: Success, final reward=1.0
# Game 560 played until step 16: Game over, final reward=0.0
# Game 561 played until step 7: Success, final reward=1.0
# Game 562 played until step 23: Game over, final reward=0.0
# Game 563 played until step 35: Success, final reward=1.0
# Game 564 played until step 12: Game over, final reward=0.0
# Game 565 played until step 68: Game over, final reward=0.0
# Game 566 played until step 62: Game over, final reward=0.0
# Game 567 played until step 15: Success, final reward=1.0
# Game 568 played until step 31: Game over, final reward=0.0
# Game 569 played until step 21: Game over, final reward=0.0
# Game 570 played until step 45: Game over, final reward=0.0
# Game 571 played until step 13: Game over, final reward=0.0
# Game 572 played until step 22: Success, final reward=1.0
# Game 573 played until step 16: Game over, final reward=0.0
# Game 574 played until step 12: Game over, final reward=0.0
# Game 575 played until step 12: Game over, final reward=0.0
# Game 576 played until step 32: Success, final reward=1.0
# Game 577 played until step 44: Success, final reward=1.0
# Game 578 played until step 20: Success, final reward=1.0
# Game 579 played until step 93: Success, final reward=1.0
# Game 580 played until step 7: Game over, final reward=0.0
# Game 581 played until step 15: Game over, final reward=0.0
# Game 582 played until step 37: Game over, final reward=0.0
# Game 583 played until step 64: Success, final reward=1.0
# Game 584 played until step 13: Game over, final reward=0.0
# Game 585 played until step 9: Game over, final reward=0.0
# Game 586 played until step 31: Success, final reward=1.0
# Game 587 played until step 22: Game over, final reward=0.0
# Game 588 played until step 72: Success, final reward=1.0
# Game 589 played until step 34: Success, final reward=1.0
# Game 590 played until step 64: Game over, final reward=0.0
# Game 591 played until step 29: Game over, final reward=0.0
# Game 592 played until step 29: Success, final reward=1.0
# Game 593 played until step 21: Success, final reward=1.0
# Game 594 played until step 44: Game over, final reward=0.0
# Game 595 played until step 35: Success, final reward=1.0
# Game 596 played until step 4: Game over, final reward=0.0
# Game 597 played until step 16: Game over, final reward=0.0
# Game 598 played until step 13: Game over, final reward=0.0
# Game 599 played until step 34: Game over, final reward=0.0
# Game 600 played until step 33: Game over, final reward=0.0
# Game 601 played until step 11: Success, final reward=1.0
# Game 602 played until step 22: Game over, final reward=0.0
# Game 603 played until step 19: Success, final reward=1.0
# Game 604 played until step 16: Game over, final reward=0.0
# Game 605 played until step 6: Game over, final reward=0.0
# Game 606 played until step 12: Success, final reward=1.0
# Game 607 played until step 7: Game over, final reward=0.0
# Game 608 played until step 3: Game over, final reward=0.0
# Game 609 played until step 11: Game over, final reward=0.0
# Game 610 played until step 23: Success, final reward=1.0
# Game 611 played until step 11: Success, final reward=1.0
# Game 612 played until step 52: Success, final reward=1.0
# Game 613 played until step 29: Game over, final reward=0.0
# Game 614 played until step 16: Success, final reward=1.0
# Game 615 played until step 23: Game over, final reward=0.0
# Game 616 played until step 40: Success, final reward=1.0
# Game 617 played until step 43: Success, final reward=1.0
# Game 618 played until step 12: Game over, final reward=0.0
# Game 619 played until step 18: Success, final reward=1.0
# Game 620 played until step 19: Game over, final reward=0.0
# Game 621 played until step 11: Game over, final reward=0.0
# Game 622 played until step 27: Game over, final reward=0.0
# Game 623 played until step 25: Game over, final reward=0.0
# Game 624 played until step 29: Success, final reward=1.0
# Game 625 played until step 30: Success, final reward=1.0
# Game 626 played until step 10: Success, final reward=1.0
# Game 627 played until step 15: Game over, final reward=0.0
# Game 628 played until step 37: Game over, final reward=0.0
# Game 629 played until step 49: Game over, final reward=0.0
# Game 630 played until step 18: Game over, final reward=0.0
# Game 631 played until step 37: Game over, final reward=0.0
# Game 632 played until step 14: Game over, final reward=0.0
# Game 633 played until step 33: Success, final reward=1.0
# Game 634 played until step 18: Game over, final reward=0.0
# Game 635 played until step 33: Success, final reward=1.0
# Game 636 played until step 37: Game over, final reward=0.0
# Game 637 played until step 8: Game over, final reward=0.0
# Game 638 played until step 40: Game over, final reward=0.0
# Game 639 played until step 11: Game over, final reward=0.0
# Game 640 played until step 22: Game over, final reward=0.0
# Game 641 played until step 16: Success, final reward=1.0
# Game 642 played until step 9: Success, final reward=1.0
# Game 643 played until step 10: Success, final reward=1.0
# Game 644 played until step 3: Game over, final reward=0.0
# Game 645 played until step 18: Game over, final reward=0.0
# Game 646 played until step 46: Game over, final reward=0.0
# Game 647 played until step 7: Game over, final reward=0.0
# Game 648 played until step 10: Game over, final reward=0.0
# Game 649 played until step 83: Success, final reward=1.0
# Game 650 played until step 41: Game over, final reward=0.0
# Game 651 played until step 7: Game over, final reward=0.0
# Game 653 played until step 47: Game over, final reward=0.0
# Game 654 played until step 27: Success, final reward=1.0
# Game 655 played until step 9: Success, final reward=1.0
# Game 656 played until step 18: Game over, final reward=0.0
# Game 657 played until step 45: Game over, final reward=0.0
# Game 658 played until step 59: Game over, final reward=0.0
# Game 659 played until step 22: Game over, final reward=0.0
# Game 660 played until step 55: Game over, final reward=0.0
# Game 661 played until step 22: Success, final reward=1.0
# Game 662 played until step 59: Success, final reward=1.0
# Game 663 played until step 16: Success, final reward=1.0
# Game 664 played until step 44: Game over, final reward=0.0
# Game 665 played until step 16: Game over, final reward=0.0
# Game 666 played until step 44: Game over, final reward=0.0
# Game 667 played until step 24: Success, final reward=1.0
# Game 668 played until step 91: Game over, final reward=0.0
# Game 669 played until step 44: Success, final reward=1.0
# Game 670 played until step 68: Success, final reward=1.0
# Game 671 played until step 23: Game over, final reward=0.0
# Game 672 played until step 55: Success, final reward=1.0
# Game 673 played until step 44: Success, final reward=1.0
# Game 674 played until step 13: Game over, final reward=0.0
# Game 675 played until step 42: Success, final reward=1.0
# Game 676 played until step 38: Success, final reward=1.0
# Game 677 played until step 47: Game over, final reward=0.0
# Game 678 played until step 18: Game over, final reward=0.0
# Game 679 played until step 15: Game over, final reward=0.0
# Game 680 played until step 42: Game over, final reward=0.0
# Game 681 played until step 7: Success, final reward=1.0
# Game 682 played until step 6: Game over, final reward=0.0
# Game 683 played until step 28: Success, final reward=1.0
# Game 684 played until step 49: Success, final reward=1.0
# Game 685 played until step 18: Success, final reward=1.0
# Game 686 played until step 9: Game over, final reward=0.0
# Game 687 played until step 20: Game over, final reward=0.0
# Game 688 played until step 7: Game over, final reward=0.0
# Game 689 played until step 26: Success, final reward=1.0
# Game 690 played until step 42: Game over, final reward=0.0
# Game 691 played until step 19: Success, final reward=1.0
# Game 692 played until step 84: Game over, final reward=0.0
# Game 693 played until step 26: Success, final reward=1.0
# Game 694 played until step 16: Success, final reward=1.0
# Game 695 played until step 49: Game over, final reward=0.0
# Game 696 played until step 34: Success, final reward=1.0
# Game 697 played until step 36: Game over, final reward=0.0
# Game 698 played until step 24: Game over, final reward=0.0
# Game 699 played until step 15: Game over, final reward=0.0
# Game 700 played until step 99: Game over, final reward=0.0
# Game 701 played until step 34: Success, final reward=1.0
# Game 702 played until step 32: Success, final reward=1.0
# Game 703 played until step 22: Game over, final reward=0.0
# Game 704 played until step 16: Game over, final reward=0.0
# Game 705 played until step 3: Game over, final reward=0.0
# Game 706 played until step 5: Game over, final reward=0.0
# Game 707 played until step 15: Success, final reward=1.0
# Game 708 played until step 71: Success, final reward=1.0
# Game 709 played until step 67: Success, final reward=1.0
# Game 710 played until step 11: Game over, final reward=0.0
# Game 711 played until step 16: Game over, final reward=0.0
# Game 712 played until step 17: Success, final reward=1.0
# Game 713 played until step 38: Game over, final reward=0.0
# Game 714 played until step 44: Game over, final reward=0.0
# Game 715 played until step 50: Success, final reward=1.0
# Game 716 played until step 21: Success, final reward=1.0
# Game 717 played until step 5: Game over, final reward=0.0
# Game 718 played until step 30: Success, final reward=1.0
# Game 719 played until step 5: Game over, final reward=0.0
# Game 720 played until step 19: Success, final reward=1.0
# Game 721 played until step 8: Game over, final reward=0.0
# Game 722 played until step 5: Game over, final reward=0.0
# Game 723 played until step 75: Success, final reward=1.0
# Game 724 played until step 9: Success, final reward=1.0
# Game 725 played until step 40: Success, final reward=1.0
# Game 726 played until step 18: Game over, final reward=0.0
# Game 727 played until step 43: Success, final reward=1.0
# Game 728 played until step 44: Game over, final reward=0.0
# Game 729 played until step 54: Game over, final reward=0.0
# Game 730 played until step 19: Success, final reward=1.0
# Game 732 played until step 48: Success, final reward=1.0
# Game 733 played until step 22: Success, final reward=1.0
# Game 734 played until step 27: Success, final reward=1.0
# Game 735 played until step 47: Game over, final reward=0.0
# Game 736 played until step 17: Success, final reward=1.0
# Game 737 played until step 25: Game over, final reward=0.0
# Game 738 played until step 19: Game over, final reward=0.0
# Game 740 played until step 17: Game over, final reward=0.0
# Game 741 played until step 21: Game over, final reward=0.0
# Game 742 played until step 48: Success, final reward=1.0
# Game 743 played until step 21: Game over, final reward=0.0
# Game 744 played until step 34: Success, final reward=1.0
# Game 745 played until step 75: Game over, final reward=0.0
# Game 746 played until step 2: Game over, final reward=0.0
# Game 747 played until step 20: Game over, final reward=0.0
# Game 748 played until step 10: Success, final reward=1.0
# Game 749 played until step 38: Game over, final reward=0.0
# Game 750 played until step 42: Game over, final reward=0.0
# Game 751 played until step 24: Success, final reward=1.0
# Game 752 played until step 13: Success, final reward=1.0
# Game 753 played until step 25: Game over, final reward=0.0
# Game 754 played until step 23: Success, final reward=1.0
# Game 755 played until step 23: Game over, final reward=0.0
# Game 756 played until step 69: Game over, final reward=0.0
# Game 757 played until step 11: Success, final reward=1.0
# Game 758 played until step 44: Success, final reward=1.0
# Game 759 played until step 15: Game over, final reward=0.0
# Game 760 played until step 48: Game over, final reward=0.0
# Game 761 played until step 16: Success, final reward=1.0
# Game 762 played until step 34: Game over, final reward=0.0
# Game 763 played until step 52: Success, final reward=1.0
# Game 765 played until step 11: Game over, final reward=0.0
# Game 766 played until step 57: Success, final reward=1.0
# Game 767 played until step 57: Game over, final reward=0.0
# Game 768 played until step 8: Game over, final reward=0.0
# Game 769 played until step 17: Success, final reward=1.0
# Game 770 played until step 67: Game over, final reward=0.0
# Game 771 played until step 9: Success, final reward=1.0
# Game 772 played until step 43: Game over, final reward=0.0
# Game 773 played until step 10: Success, final reward=1.0
# Game 774 played until step 26: Success, final reward=1.0
# Game 775 played until step 21: Game over, final reward=0.0
# Game 776 played until step 48: Game over, final reward=0.0
# Game 777 played until step 14: Success, final reward=1.0
# Game 778 played until step 13: Success, final reward=1.0
# Game 779 played until step 37: Game over, final reward=0.0
# Game 780 played until step 15: Success, final reward=1.0
# Game 781 played until step 37: Game over, final reward=0.0
# Game 782 played until step 9: Game over, final reward=0.0
# Game 783 played until step 27: Success, final reward=1.0
# Game 784 played until step 82: Success, final reward=1.0
# Game 785 played until step 50: Success, final reward=1.0
# Game 786 played until step 7: Game over, final reward=0.0
# Game 787 played until step 5: Game over, final reward=0.0
# Game 788 played until step 9: Game over, final reward=0.0
# Game 789 played until step 21: Success, final reward=1.0
# Game 790 played until step 19: Success, final reward=1.0
# Game 791 played until step 24: Game over, final reward=0.0
# Game 792 played until step 25: Game over, final reward=0.0
# Game 793 played until step 38: Game over, final reward=0.0
# Game 794 played until step 27: Success, final reward=1.0
# Game 795 played until step 34: Game over, final reward=0.0
# Game 796 played until step 10: Success, final reward=1.0
# Game 797 played until step 22: Game over, final reward=0.0
# Game 798 played until step 13: Game over, final reward=0.0
# Game 799 played until step 28: Game over, final reward=0.0
# Game 800 played until step 29: Success, final reward=1.0
# Game 801 played until step 77: Game over, final reward=0.0
# Game 802 played until step 64: Game over, final reward=0.0
# Game 803 played until step 57: Success, final reward=1.0
# Game 804 played until step 41: Game over, final reward=0.0
# Game 805 played until step 59: Game over, final reward=0.0
# Game 806 played until step 32: Success, final reward=1.0
# Game 807 played until step 42: Success, final reward=1.0
# Game 808 played until step 32: Game over, final reward=0.0
# Game 809 played until step 6: Game over, final reward=0.0
# Game 810 played until step 9: Game over, final reward=0.0
# Game 811 played until step 13: Game over, final reward=0.0
# Game 812 played until step 17: Game over, final reward=0.0
# Game 814 played until step 53: Game over, final reward=0.0
# Game 815 played until step 22: Game over, final reward=0.0
# Game 816 played until step 29: Success, final reward=1.0
# Game 817 played until step 14: Success, final reward=1.0
# Game 818 played until step 16: Game over, final reward=0.0
# Game 819 played until step 16: Game over, final reward=0.0
# Game 820 played until step 57: Game over, final reward=0.0
# Game 821 played until step 18: Game over, final reward=0.0
# Game 822 played until step 28: Game over, final reward=0.0
# Game 823 played until step 39: Game over, final reward=0.0
# Game 824 played until step 39: Success, final reward=1.0
# Game 825 played until step 60: Success, final reward=1.0
# Game 826 played until step 48: Game over, final reward=0.0
# Game 827 played until step 28: Game over, final reward=0.0
# Game 828 played until step 28: Game over, final reward=0.0
# Game 829 played until step 23: Success, final reward=1.0
# Game 830 played until step 8: Game over, final reward=0.0
# Game 831 played until step 23: Success, final reward=1.0
# Game 832 played until step 31: Game over, final reward=0.0
# ...
# Game 1715 played until step 12: Success, final reward=1.0
# Game 1716 played until step 11: Success, final reward=1.0
# Game 1717 played until step 55: Game over, final reward=0.0
# Game 1718 played until step 25: Success, final reward=1.0
# Game 1719 played until step 6: Game over, final reward=0.0
# Game 1720 played until step 20: Success, final reward=1.0
# Game 1721 played until step 14: Success, final reward=1.0
# Game 1722 played until step 39: Success, final reward=1.0
# Game 1723 played until step 10: Success, final reward=1.0
# Game 1724 played until step 20: Success, final reward=1.0
# Game 1725 played until step 41: Success, final reward=1.0
# Game 1726 played until step 13: Success, final reward=1.0
# Game 1727 played until step 18: Game over, final reward=0.0
# Game 1728 played until step 45: Success, final reward=1.0
# Game 1729 played until step 12: Success, final reward=1.0
# Game 1731 played until step 6: Success, final reward=1.0
# Game 1732 played until step 12: Success, final reward=1.0
# Game 1733 played until step 19: Game over, final reward=0.0
# Game 1734 played until step 2: Game over, final reward=0.0
# Game 1735 played until step 32: Success, final reward=1.0
# Game 1736 played until step 23: Success, final reward=1.0
# Game 1737 played until step 29: Game over, final reward=0.0
# Game 1738 played until step 14: Success, final reward=1.0
# Game 1739 played until step 91: Success, final reward=1.0
# Game 1740 played until step 23: Success, final reward=1.0
# Game 1741 played until step 15: Success, final reward=1.0
# Game 1742 played until step 71: Game over, final reward=0.0
# Game 1743 played until step 13: Success, final reward=1.0
# Game 1744 played until step 11: Success, final reward=1.0
# Game 1745 played until step 43: Game over, final reward=0.0
# Game 1746 played until step 53: Success, final reward=1.0
# Game 1747 played until step 20: Success, final reward=1.0
# Game 1748 played until step 62: Success, final reward=1.0
# Game 1749 played until step 40: Success, final reward=1.0
# Game 1750 played until step 26: Game over, final reward=0.0
# Game 1751 played until step 19: Success, final reward=1.0
# Game 1753 played until step 14: Game over, final reward=0.0
# Game 1754 played until step 8: Success, final reward=1.0
# Game 1755 played until step 50: Success, final reward=1.0
# Game 1756 played until step 65: Success, final reward=1.0
# Game 1757 played until step 44: Success, final reward=1.0
# Game 1758 played until step 8: Success, final reward=1.0
# Game 1760 played until step 26: Success, final reward=1.0
# Game 1761 played until step 67: Game over, final reward=0.0
# Game 1762 played until step 27: Success, final reward=1.0
# Game 1763 played until step 82: Success, final reward=1.0
# Game 1764 played until step 38: Success, final reward=1.0
# Game 1765 played until step 13: Game over, final reward=0.0
# Game 1766 played until step 20: Game over, final reward=0.0
# Game 1767 played until step 33: Success, final reward=1.0
# Game 1768 played until step 40: Success, final reward=1.0
# Game 1769 played until step 6: Game over, final reward=0.0
# Game 1770 played until step 9: Success, final reward=1.0
# Game 1771 played until step 17: Success, final reward=1.0
# Game 1772 played until step 67: Game over, final reward=0.0
# Game 1773 played until step 8: Success, final reward=1.0
# Game 1774 played until step 16: Game over, final reward=0.0
# Game 1775 played until step 28: Success, final reward=1.0
# Game 1776 played until step 65: Game over, final reward=0.0
# Game 1777 played until step 58: Success, final reward=1.0
# Game 1778 played until step 23: Success, final reward=1.0
# Game 1779 played until step 15: Game over, final reward=0.0
# Game 1780 played until step 37: Success, final reward=1.0
# Game 1781 played until step 34: Success, final reward=1.0
# Game 1782 played until step 36: Game over, final reward=0.0
# Game 1783 played until step 3: Game over, final reward=0.0
# Game 1785 played until step 25: Game over, final reward=0.0
# Game 1786 played until step 7: Game over, final reward=0.0
# Game 1787 played until step 71: Success, final reward=1.0
# Game 1788 played until step 18: Game over, final reward=0.0
# Game 1789 played until step 59: Success, final reward=1.0
# Game 1790 played until step 42: Success, final reward=1.0
# Game 1791 played until step 13: Game over, final reward=0.0
# Game 1792 played until step 46: Success, final reward=1.0
# Game 1793 played until step 82: Game over, final reward=0.0
# Game 1794 played until step 13: Game over, final reward=0.0
# Game 1795 played until step 28: Game over, final reward=0.0
# Game 1796 played until step 27: Game over, final reward=0.0
# Game 1797 played until step 32: Game over, final reward=0.0
# Game 1798 played until step 33: Game over, final reward=0.0
# Game 1799 played until step 12: Game over, final reward=0.0
# Game 1800 played until step 9: Game over, final reward=0.0
# Game 1801 played until step 30: Game over, final reward=0.0
# Game 1802 played until step 32: Success, final reward=1.0
# Game 1803 played until step 30: Game over, final reward=0.0
# Game 1804 played until step 13: Game over, final reward=0.0
# Game 1805 played until step 10: Game over, final reward=0.0
# Game 1806 played until step 8: Game over, final reward=0.0
# Game 1807 played until step 37: Game over, final reward=0.0
# Game 1808 played until step 74: Game over, final reward=0.0
# Game 1809 played until step 13: Game over, final reward=0.0
# Game 1810 played until step 26: Success, final reward=1.0
# Game 1811 played until step 68: Success, final reward=1.0
# Game 1812 played until step 17: Game over, final reward=0.0
# Game 1813 played until step 20: Game over, final reward=0.0
# Game 1814 played until step 21: Success, final reward=1.0
# Game 1815 played until step 28: Success, final reward=1.0
# Game 1816 played until step 10: Game over, final reward=0.0
# Game 1817 played until step 71: Success, final reward=1.0
# Game 1818 played until step 47: Game over, final reward=0.0
# Game 1819 played until step 43: Success, final reward=1.0
# Game 1820 played until step 64: Success, final reward=1.0
# Game 1821 played until step 14: Success, final reward=1.0
# Game 1822 played until step 7: Game over, final reward=0.0
# Game 1823 played until step 12: Success, final reward=1.0
# Game 1824 played until step 47: Success, final reward=1.0
# Game 1825 played until step 34: Success, final reward=1.0
# Game 1826 played until step 44: Success, final reward=1.0
# Game 1827 played until step 13: Success, final reward=1.0
# Game 1828 played until step 28: Success, final reward=1.0
# Game 1829 played until step 32: Success, final reward=1.0
# Game 1830 played until step 63: Success, final reward=1.0
# Game 1831 played until step 9: Success, final reward=1.0
# Game 1832 played until step 35: Success, final reward=1.0
# Game 1833 played until step 99: Success, final reward=1.0
# Game 1834 played until step 14: Success, final reward=1.0
# Game 1835 played until step 50: Game over, final reward=0.0
# Game 1836 played until step 22: Success, final reward=1.0
# Game 1837 played until step 27: Success, final reward=1.0
# Game 1838 played until step 13: Game over, final reward=0.0
# Game 1839 played until step 38: Game over, final reward=0.0
# Game 1840 played until step 11: Game over, final reward=0.0
# Game 1841 played until step 47: Success, final reward=1.0
# Game 1842 played until step 35: Success, final reward=1.0
# Game 1843 played until step 11: Game over, final reward=0.0
# Game 1844 played until step 37: Success, final reward=1.0
# Game 1845 played until step 70: Game over, final reward=0.0
# Game 1846 played until step 78: Game over, final reward=0.0
# Game 1847 played until step 36: Success, final reward=1.0
# Game 1848 played until step 12: Success, final reward=1.0
# Game 1849 played until step 77: Success, final reward=1.0
# Game 1851 played until step 22: Success, final reward=1.0
# Game 1852 played until step 44: Success, final reward=1.0
# Game 1853 played until step 23: Game over, final reward=0.0
# Game 1854 played until step 63: Success, final reward=1.0
# Game 1855 played until step 18: Game over, final reward=0.0
# Game 1856 played until step 66: Success, final reward=1.0
# Game 1857 played until step 57: Game over, final reward=0.0
# Game 1858 played until step 12: Success, final reward=1.0
# Game 1859 played until step 22: Success, final reward=1.0
# Game 1860 played until step 19: Success, final reward=1.0
# Game 1861 played until step 9: Success, final reward=1.0
# Game 1862 played until step 48: Game over, final reward=0.0
# Game 1863 played until step 25: Success, final reward=1.0
# Game 1864 played until step 33: Success, final reward=1.0
# Game 1865 played until step 34: Game over, final reward=0.0
# Game 1866 played until step 13: Game over, final reward=0.0
# Game 1867 played until step 43: Game over, final reward=0.0
# Game 1868 played until step 9: Game over, final reward=0.0
# Game 1869 played until step 16: Game over, final reward=0.0
# Game 1870 played until step 71: Game over, final reward=0.0
# Game 1871 played until step 9: Success, final reward=1.0
# Game 1872 played until step 57: Success, final reward=1.0
# Game 1873 played until step 19: Success, final reward=1.0
# Game 1875 played until step 49: Success, final reward=1.0
# Game 1876 played until step 51: Success, final reward=1.0
# Game 1877 played until step 58: Success, final reward=1.0
# Game 1878 played until step 18: Success, final reward=1.0
# Game 1879 played until step 16: Success, final reward=1.0
# Game 1880 played until step 28: Success, final reward=1.0
# Game 1881 played until step 13: Success, final reward=1.0
# Game 1883 played until step 26: Success, final reward=1.0
# Game 1884 played until step 18: Success, final reward=1.0
# Game 1885 played until step 16: Success, final reward=1.0
# Game 1886 played until step 12: Game over, final reward=0.0
# Game 1887 played until step 21: Success, final reward=1.0
# Game 1888 played until step 21: Game over, final reward=0.0
# Game 1889 played until step 96: Success, final reward=1.0
# Game 1890 played until step 33: Success, final reward=1.0
# Game 1891 played until step 70: Game over, final reward=0.0
# Game 1892 played until step 44: Success, final reward=1.0
# Game 1893 played until step 17: Game over, final reward=0.0
# Game 1894 played until step 17: Success, final reward=1.0
# Game 1895 played until step 50: Game over, final reward=0.0
# Game 1896 played until step 79: Game over, final reward=0.0
# Game 1897 played until step 20: Success, final reward=1.0
# Game 1898 played until step 22: Success, final reward=1.0
# Game 1899 played until step 55: Success, final reward=1.0
# Game 1900 played until step 34: Success, final reward=1.0
# Game 1901 played until step 28: Success, final reward=1.0
# Game 1902 played until step 11: Success, final reward=1.0
# Game 1903 played until step 42: Success, final reward=1.0
# Game 1904 played until step 22: Success, final reward=1.0
# Game 1905 played until step 17: Success, final reward=1.0
# Game 1906 played until step 37: Success, final reward=1.0
# Game 1907 played until step 18: Success, final reward=1.0
# Game 1908 played until step 22: Game over, final reward=0.0
# Game 1909 played until step 50: Game over, final reward=0.0
# Game 1910 played until step 58: Game over, final reward=0.0
# Game 1911 played until step 23: Success, final reward=1.0
# Game 1912 played until step 7: Success, final reward=1.0
# Game 1913 played until step 59: Game over, final reward=0.0
# Game 1914 played until step 51: Success, final reward=1.0
# Game 1915 played until step 14: Game over, final reward=0.0
# Game 1916 played until step 9: Success, final reward=1.0
# Game 1917 played until step 20: Success, final reward=1.0
# Game 1918 played until step 38: Success, final reward=1.0
# Game 1919 played until step 16: Game over, final reward=0.0
# Game 1920 played until step 55: Success, final reward=1.0
# Game 1921 played until step 13: Success, final reward=1.0
# Game 1922 played until step 53: Game over, final reward=0.0
# Game 1923 played until step 80: Success, final reward=1.0
# Game 1924 played until step 19: Game over, final reward=0.0
# Game 1925 played until step 43: Game over, final reward=0.0
# Game 1926 played until step 27: Success, final reward=1.0
# Game 1927 played until step 56: Game over, final reward=0.0
# Game 1928 played until step 12: Game over, final reward=0.0
# Game 1929 played until step 7: Game over, final reward=0.0
# Game 1930 played until step 76: Success, final reward=1.0
# Game 1931 played until step 35: Success, final reward=1.0
# Game 1932 played until step 23: Success, final reward=1.0
# Game 1933 played until step 21: Success, final reward=1.0
# Game 1934 played until step 8: Success, final reward=1.0
# Game 1935 played until step 59: Success, final reward=1.0
# Game 1936 played until step 15: Success, final reward=1.0
# Game 1937 played until step 10: Success, final reward=1.0
# Game 1938 played until step 12: Success, final reward=1.0
# Game 1939 played until step 16: Success, final reward=1.0
# Game 1940 played until step 35: Game over, final reward=0.0
# Game 1941 played until step 16: Success, final reward=1.0
# Game 1942 played until step 49: Success, final reward=1.0
# Game 1944 played until step 35: Game over, final reward=0.0
# Game 1945 played until step 37: Success, final reward=1.0
# Game 1946 played until step 21: Success, final reward=1.0
# Game 1947 played until step 19: Success, final reward=1.0
# Game 1948 played until step 40: Success, final reward=1.0
# Game 1949 played until step 19: Game over, final reward=0.0
# Game 1951 played until step 9: Success, final reward=1.0
# Game 1952 played until step 51: Success, final reward=1.0
# Game 1953 played until step 35: Success, final reward=1.0
# Game 1954 played until step 27: Success, final reward=1.0
# Game 1955 played until step 23: Game over, final reward=0.0
# Game 1956 played until step 51: Success, final reward=1.0
# Game 1957 played until step 22: Game over, final reward=0.0
# Game 1958 played until step 13: Success, final reward=1.0
# Game 1959 played until step 38: Game over, final reward=0.0
# Game 1960 played until step 31: Game over, final reward=0.0
# Game 1961 played until step 10: Success, final reward=1.0
# Game 1963 played until step 23: Success, final reward=1.0
# Game 1964 played until step 14: Game over, final reward=0.0
# Game 1965 played until step 46: Game over, final reward=0.0
# Game 1966 played until step 44: Success, final reward=1.0
# Game 1967 played until step 12: Success, final reward=1.0
# Game 1968 played until step 56: Success, final reward=1.0
# Game 1969 played until step 35: Success, final reward=1.0
# Game 1970 played until step 16: Success, final reward=1.0
# Game 1971 played until step 47: Success, final reward=1.0
# Game 1972 played until step 73: Success, final reward=1.0
# Game 1973 played until step 41: Success, final reward=1.0
# Game 1974 played until step 41: Success, final reward=1.0
# Game 1976 played until step 26: Success, final reward=1.0
# Game 1977 played until step 19: Success, final reward=1.0
# Game 1978 played until step 8: Game over, final reward=0.0
# Game 1979 played until step 12: Success, final reward=1.0
# Game 1980 played until step 79: Success, final reward=1.0
# Game 1981 played until step 28: Success, final reward=1.0
# Game 1982 played until step 52: Game over, final reward=0.0
# Game 1983 played until step 29: Success, final reward=1.0
# Game 1984 played until step 22: Success, final reward=1.0
# Game 1985 played until step 29: Success, final reward=1.0
# Game 1986 played until step 34: Game over, final reward=0.0
# Game 1987 played until step 31: Game over, final reward=0.0
# Game 1989 played until step 28: Game over, final reward=0.0
# Game 1990 played until step 7: Game over, final reward=0.0
# Game 1991 played until step 16: Game over, final reward=0.0
# Game 1993 played until step 29: Success, final reward=1.0
# Game 1994 played until step 41: Game over, final reward=0.0
# Game 1995 played until step 36: Success, final reward=1.0
# Game 1996 played until step 25: Success, final reward=1.0
# Game 1997 played until step 62: Game over, final reward=0.0
# Game 1998 played until step 20: Success, final reward=1.0
# Game 1999 played until step 50: Success, final reward=1.0
# Percent of succesful episodes: 42.8%

# %% [markdown]
# ### Some statistics on network performance

# %% [markdown]
# We can see that the network beings to consistly reach the goal around the 750 episode mark.

# %%
plt.plot(rList)

# %% [markdown]
# It also begins to progress through the environment for longer than chance aroudn the 750 mark as well.

# %%
plt.plot(jList)
